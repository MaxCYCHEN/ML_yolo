# %% [markdown]
# # 1. Install the python library
# - Using CMD window is a better choice for long log
# - Better to install in a new python env
# - Ref: https://github.com/ultralytics/ultralytics/tree/main
# - Ref: https://github.com/PINTO0309/onnx2tf
# - Ref: https://pypi.org/project/ethos-u-vela/

# %%
# !pip install ultralytics

# %%
# !pip install ethos-u-vela==3.10.0

# %%
# !pip install -U tensorflow==2.15.0
# !pip install -U onnx==1.15.0
# !pip install -U nvidia-pyindex
# !pip install -U onnx-graphsurgeon
# !pip install -U onnxruntime==1.16.3
# !pip install -U onnxsim==0.4.33
# !pip install -U simple_onnx_processing_tools
# !pip install -U onnx2tf
# !pip install -U h5py==3.7.0
# !pip install -U psutil==5.9.5
# !pip install -U ml_dtypes==0.2.0

# %% [markdown]
# # 2. Prepare the yolov8-n model

# %%
from ultralytics import YOLO
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load a model
model = YOLO('yolov8n.pt')  # load an official model
#model = YOLO('path/to/best.pt')  # load a custom trained model

# Export the model as onnx
model.export(format='onnx', imgsz=320)

# Export the model as tflite
# <ISSUE>: This int8.tflite doesn't have quantization parameters, so can't be converted to vela at the next step.
#model.export(format='tflite', int8=True)
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.9 torch-2.1.2+cpu CPU (12th Gen Intel Core(TM) i7-12700)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 84, 2100) (6.2 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 0.4s, saved as 'yolov8n.onnx' (12.1 MB)
#
# Export complete (1.9s)
# Results saved to C:\Users\USER\Desktop\ML\ultralytics
# Predict:         yolo predict task=detect model=yolov8n.onnx imgsz=320
# Validate:        yolo val task=detect model=yolov8n.onnx imgsz=320 data=coco.yaml
# Visualize:       https://netron.app
# 'yolov8n.onnx'

# %% [markdown]
# # 3. Convert to tflite int8 model
# - Move the `yolov8n.onnx` to a directory you like
# - Using CMD window is a better choice for long log

# %%
import os

cov_dir_name = 'yolov8n_saved_model_320'
cwd = os.getcwd()
os.chdir(os.path.join(cwd, cov_dir_name))

#!onnx2tf -i yolov8n.onnx -oiqt -qt per-tensor
# !onnx2tf -i yolov8n.onnx -nuo -oiqt -qt per-tensor

os.chdir(cwd) # Change back to original path
# Out:
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: images shape: [1, 3, 320, 320] dtype: float32
#
# INFO: 2 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.0/conv/Conv
# INFO:  input_name.1: images shape: [1, 3, 320, 320] dtype: float32
# INFO:  input_name.2: model.0.conv.weight shape: [16, 3, 3, 3] dtype: float32
# INFO:  input_name.3: model.0.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad/Pad:0 shape: (1, 322, 322, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.0/act/Sigmoid
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.0/act/Mul
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_3/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.1/conv/Conv
# INFO:  input_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.1.conv.weight shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_1/Pad:0 shape: (1, 162, 162, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.1/act/Sigmoid
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.1/act/Mul
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_7/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 8 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv1/conv/Conv
# INFO:  input_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.2.cv1.conv.weight shape: [32, 32, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_7/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 9 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 10 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_11/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 11 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.2/Split
# INFO:  input_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Split_137 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.2/Split_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.2: wa/model.2/Split_output_1 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_11/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split/split:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split/split:1 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 12 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv1.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv1.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split/split:1 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 13 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 14 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_15/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 15 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv2.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv2.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_15/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 16 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 17 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_19/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 18 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.2/m.0/Add
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/Add_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split/split:1 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_19/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 19 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.2/Concat
# INFO:  input_name.1: wa/model.2/Split_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/Split_output_1 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.3: wa/model.2/m.0/Add_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split/split:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split/split:1 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_6/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 3
# INFO:  output.1.output: name: tf.concat/concat:0 shape: (1, 80, 80, 48) dtype: <dtype: 'float32'>
#
# INFO: 20 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 80, 80] dtype: float32
# INFO:  input_name.2: model.2.cv2.conv.weight shape: [32, 48, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat/concat:0 shape: (1, 80, 80, 48) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 48, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 21 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 22 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_25/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 23 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.3/conv/Conv
# INFO:  input_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.3.conv.weight shape: [64, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.3.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_2/Pad:0 shape: (1, 82, 82, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 24 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.3/act/Sigmoid
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 25 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.3/act/Mul
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_29/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 26 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv1/conv/Conv
# INFO:  input_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.cv1.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_29/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 27 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 28 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_33/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 29 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.4/Split
# INFO:  input_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: onnx::Split_157 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.4/Split_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.2: wa/model.4/Split_output_1 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_33/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_1/split:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_1/split:1 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 30 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_1/split:1 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 31 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 32 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_37/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 33 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_37/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 34 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 35 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_41/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 36 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.0/Add
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_1/split:1 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_41/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 37 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_13/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 38 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 39 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_47/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 40 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_47/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 41 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 42 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_51/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 43 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.1/Add
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_13/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_51/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_17/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 44 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.4/Concat
# INFO:  input_name.1: wa/model.4/Split_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/Split_output_1 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.3: wa/model.4/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.4: wa/model.4/m.1/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split_1/split:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split_1/split:1 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_13/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.4.input3: name: tf.math.add_17/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.5.axis: val: 3
# INFO:  output.1.output: name: tf.concat_1/concat:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: model.4.cv2.conv.weight shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_1/concat:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 46 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 47 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_57/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 48 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.5/conv/Conv
# INFO:  input_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.5.conv.weight shape: [128, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.5.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_3/Pad:0 shape: (1, 42, 42, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_19/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 49 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.5/act/Sigmoid
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 50 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.5/act/Mul
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_61/Mul:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 51 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/cv1/conv/Conv
# INFO:  input_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  input_name.2: model.6.cv1.conv.weight shape: [128, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.cv1.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_61/Mul:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 52 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 53 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_65/Mul:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
#
# INFO: 54 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.6/Split
# INFO:  input_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 20, 20] dtype: float32
# INFO:  input_name.2: onnx::Split_184 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.6/Split_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.2: wa/model.6/Split_output_1 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_65/Mul:0 shape: (1, 20, 20, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_2/split:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_2/split:1 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 55 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv1.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_2/split:1 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_21/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 56 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_21/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 57 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_21/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_69/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 58 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv2.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_69/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 59 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_22/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 60 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_22/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_73/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 61 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.6/m.0/Add
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/Add_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_2/split:1 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_73/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_24/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 62 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.1/cv1/conv/Conv
# INFO:  input_name.1: wa/model.6/m.0/Add_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: model.6.m.1.cv1.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.1.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_24/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_25/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 63 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 64 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.1/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/m.1/cv1/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_79/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 65 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.1/cv2/conv/Conv
# INFO:  input_name.1: wa/model.6/m.1/cv1/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: model.6.m.1.cv2.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.1.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_79/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_26/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 66 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.1/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.1/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv2/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_26/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_18/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 67 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.1/cv2/act/Mul
# INFO:  input_name.1: wa/model.6/m.1/cv2/conv/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.6/m.1/cv2/act/Sigmoid_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv2/act/Mul_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_26/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_18/Sigmoid:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_83/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 68 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.6/m.1/Add
# ...
# INFO:  input_name.2: wa/model.22/Reshape_1_output_0 shape: [1, 144, 400] dtype: float32
# INFO:  input_name.3: wa/model.22/Reshape_2_output_0 shape: [1, 144, 100] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_3_output_0 shape: [1, 144, 2100] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.reshape_2/Reshape:0 shape: (1, 144, 1600) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.reshape_5/Reshape:0 shape: (1, 144, 400) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.reshape_8/Reshape:0 shape: (1, 144, 100) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 2
# INFO:  output.1.output: name: tf.concat_16/concat:0 shape: (1, 144, 2100) dtype: <dtype: 'float32'>
#
# INFO: 218 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.22/Split
# INFO:  input_name.1: wa/model.22/Concat_3_output_0 shape: [1, 144, 2100] dtype: float32
# INFO:  input_name.2: onnx::Split_388 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.22/Split_output_0 shape: [1, 64, 2100] dtype: float32
# INFO:  output_name.2: wa/model.22/Split_output_1 shape: [1, 80, 2100] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.concat_16/concat:0 shape: (1, 144, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 1
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice/StridedSlice:0 shape: (1, 64, 2100) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 80, 2100) dtype: <dtype: 'float32'>
#
# INFO: 219 / 234
# INFO: onnx_op_type: Reshape onnx_op_name: wa/model.22/dfl/Reshape
# INFO:  input_name.1: wa/model.22/Split_output_0 shape: [1, 64, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/dfl/Constant_output_0 shape: [4] dtype: int64
# INFO:  output_name.1: wa/model.22/dfl/Reshape_output_0 shape: [1, 4, 16, 2100] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.strided_slice/StridedSlice:0 shape: (1, 64, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 4, 16, 2100]
# INFO:  output.1.output: name: tf.reshape_11/Reshape:0 shape: (1, 4, 16, 2100) dtype: <dtype: 'float32'>
#
# INFO: 220 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.22/Sigmoid
# INFO:  input_name.1: wa/model.22/Split_output_1 shape: [1, 80, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Sigmoid_output_0 shape: [1, 80, 2100] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 80, 2100) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_57/Sigmoid:0 shape: (1, 80, 2100) dtype: <dtype: 'float32'>
#
# INFO: 221 / 234
# INFO: onnx_op_type: Transpose onnx_op_name: wa/model.22/dfl/Transpose
# INFO:  input_name.1: wa/model.22/dfl/Reshape_output_0 shape: [1, 4, 16, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/Transpose_output_0 shape: [1, 16, 4, 2100] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_11/Reshape:0 shape: (1, 4, 16, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 1, 3]
# INFO:  output.1.output: name: tf.compat.v1.transpose_19/transpose:0 shape: (1, 16, 4, 2100) dtype: <dtype: 'float32'>
#
# INFO: 222 / 234
# INFO: onnx_op_type: Softmax onnx_op_name: wa/model.22/dfl/Softmax
# INFO:  input_name.1: wa/model.22/dfl/Transpose_output_0 shape: [1, 16, 4, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/Softmax_output_0 shape: [1, 16, 4, 2100] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.compat.v1.transpose_20/transpose:0 shape: (1, 4, 2100, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 1
# INFO:  output.1.output: name: tf.compat.v1.transpose_21/transpose:0 shape: (1, 16, 4, 2100) dtype: <dtype: 'float32'>
#
# INFO: 223 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.22/dfl/conv/Conv
# INFO:  input_name.1: wa/model.22/dfl/Softmax_output_0 shape: [1, 16, 4, 2100] dtype: float32
# INFO:  input_name.2: model.22.dfl.conv.weight shape: [1, 16, 1, 1] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/conv/Conv_output_0 shape: [1, 1, 4, 2100] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_22/transpose:0 shape: (1, 4, 2100, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_63/convolution:0 shape: (1, 4, 2100, 1) dtype: <dtype: 'float32'>
#
# INFO: 224 / 234
# INFO: onnx_op_type: Reshape onnx_op_name: wa/model.22/dfl/Reshape_1
# INFO:  input_name.1: wa/model.22/dfl/conv/Conv_output_0 shape: [1, 1, 4, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/dfl/Constant_1_output_0 shape: [3] dtype: int64
# INFO:  output_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 2100] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_25/transpose:0 shape: (1, 1, 4, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 4, 2100]
# INFO:  output.1.output: name: tf.reshape_14/Reshape:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
#
# INFO: 225 / 234
# INFO: onnx_op_type: Slice onnx_op_name: wa/model.22/Slice
# INFO:  input_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_4_output_0 shape: [1] dtype: int64
# INFO:  input_name.3: wa/model.22/Div_output_0 shape: [1] dtype: int64
# INFO:  input_name.4: wa/model.22/Constant_3_output_0 shape: [1] dtype: int64
# INFO:  output_name.1: wa/model.22/Slice_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: strided_slice
# INFO:  input.1.input_: name: tf.reshape_14/Reshape:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.begin: shape: (1,) dtype: int64
# INFO:  input.3.end: shape: (1,) dtype: int64
# INFO:  input.4.strides:
# INFO:  output.1.output: name: tf.strided_slice_2/StridedSlice:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 226 / 234
# INFO: onnx_op_type: Slice onnx_op_name: wa/model.22/Slice_1
# INFO:  input_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Div_output_0 shape: (1,) dtype: int64
# INFO:  input_name.3: wa/model.22/Mul_1_output_0 shape: [1] dtype: int64
# INFO:  input_name.4: wa/model.22/Constant_3_output_0 shape: (1,) dtype: int64
# INFO:  output_name.1: wa/model.22/Slice_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: strided_slice
# INFO:  input.1.input_: name: tf.reshape_14/Reshape:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.begin: shape: (1,) dtype: int64
# INFO:  input.3.end: shape: (1,) dtype: int64
# INFO:  input.4.strides:
# INFO:  output.1.output: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 227 / 234
# INFO: onnx_op_type: Sub onnx_op_name: wa/model.22/Sub
# INFO:  input_name.1: wa/model.22/Constant_9_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Slice_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Sub_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: shape: (1, 2, 2100) dtype: float32
# INFO:  input.2.y: name: tf.strided_slice_2/StridedSlice:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract/Sub:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 228 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.22/Add_1
# INFO:  input_name.1: wa/model.22/Constant_9_output_0 shape: (1, 2, 2100) dtype: float32
# INFO:  input_name.2: wa/model.22/Slice_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Add_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: shape: (1, 2, 2100) dtype: float32
# INFO:  input.2.y: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_75/Add:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 229 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.22/Add_2
# INFO:  input_name.1: wa/model.22/Sub_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Add_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.subtract/Sub:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_75/Add:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_76/Add:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 230 / 234
# INFO: onnx_op_type: Sub onnx_op_name: wa/model.22/Sub_1
# INFO:  input_name.1: wa/model.22/Add_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Sub_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.math.add_75/Add:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.subtract/Sub:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_1/Sub:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 231 / 234
# INFO: onnx_op_type: Div onnx_op_name: wa/model.22/Div_1
# INFO:  input_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_11_output_0 shape: [] dtype: float32
# INFO:  output_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.add_76/Add:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide/truediv:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
#
# INFO: 232 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_4
# INFO:  input_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_1_output_0 shape: [1, 2, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 2100] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.divide/truediv:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.subtract_1/Sub:0 shape: (1, 2, 2100) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_20/concat:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
#
# INFO: 233 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.22/Mul_2
# INFO:  input_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_12_output_0 shape: [1, 2100] dtype: float32
# INFO:  output_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 2100] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.concat_20/concat:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 2100) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_252/Mul:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
#
# INFO: 234 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_5
# INFO:  input_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 2100] dtype: float32
# INFO:  input_name.2: wa/model.22/Sigmoid_output_0 shape: [1, 80, 2100] dtype: float32
# INFO:  output_name.1: output0 shape: [1, 84, 2100] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.multiply_252/Mul:0 shape: (1, 4, 2100) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.sigmoid_57/Sigmoid:0 shape: (1, 80, 2100) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_21/concat:0 shape: (1, 84, 2100) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# saved_model output complete!
# Float32 tflite output complete!
# Float16 tflite output complete!
# Input signature information for quantization
# signature_name: serving_default
# input_name.0: images shape: (1, 320, 320, 3) dtype: <dtype: 'float32'>
# Dynamic Range Quantization tflite output complete!
# INT8 Quantization tflite output complete!
# Full INT8 Quantization tflite output complete!
# INT8 Quantization with int16 activations tflite output complete!
# Full INT8 Quantization with int16 activations tflite output complete!
# WARNING:tensorflow:From C:\ProgramData\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 395, % non-converted = 37.47 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f32: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 526, % non-converted = 28.14 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f16: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 131)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 86, Total Ops 395, % non-converted = 21.77 %
#  * 86 ARITH ops
#
# - arith.constant:   86 occurrences  (f32: 69, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (uq_8: 62)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 395, % non-converted = 37.47 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f32: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 395, % non-converted = 37.47 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f32: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 395, % non-converted = 37.47 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f32: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 148, Total Ops 395, % non-converted = 37.47 %
#  * 148 ARITH ops
#
# - arith.constant:  148 occurrences  (f32: 131, i32: 17)
#
#
#
#   (f32: 8)
#   (f32: 19)
#   (f32: 64)
#   (f32: 58)
#   (f32: 3)
#   (f32: 59)
#   (f32: 7)
#   (f32: 5)
#   (f32: 2)
#   (f32: 1)
#   (f32: 8)
#   (f32: 4)
#   (f32: 2)
#   (f32: 4)

# %% [markdown]
# # 4. Convert to vela tflite
# - This yolov8-n model need ethos-u-vela==3.10.0

# %%
import os

cov_dir_name = 'yolov8n_saved_model_320'
cwd = os.getcwd()
os.chdir(os.path.join(cwd, cov_dir_name, 'saved_model'))

# !vela --accelerator-config ethos-u55-128 yolov8n_full_integer_quant.tflite --optimise Size
#!vela --accelerator-config ethos-u55-128 yolov8n_full_integer_quant.tflite --optimise Performance

os.chdir(cwd) # Change back to original path
# Out:
# Warning: Using internal-default values for system configuration
# Warning: Using internal-default values for memory mode
# Warning: TRANSPOSE 'model_13/tf.compat.v1.transpose_20/transpose;model_13/tf.compat.v1.transpose_19/transpose/perm;model_13/tf.compat.v1.transpose_19/transpose;model_13/tf.compat.v1.transpose_20/transpose/perm1' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 4, 16, 2100] and permutation is: [0 1 3 2]
# Warning: TRANSPOSE 'model_13/tf.compat.v1.transpose_2/transpose' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 40, 40, 144] and permutation is: [0 3 1 2]
# Warning: TRANSPOSE 'model_13/tf.compat.v1.transpose_7/transpose' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 20, 20, 144] and permutation is: [0 3 1 2]
# Warning: TRANSPOSE 'model_13/tf.compat.v1.transpose_12/transpose' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 10, 10, 144] and permutation is: [0 3 1 2]
# <nng.Tensor 'model_13/tf.compat.v1.transpose_7/transpose_npu' shape=[1, 144, 20, 20] dtype=int8> adding consumer <nng.Operation 'model_13/tf.reshape_5/Reshape' type=Memcpy>
# <nng.Tensor 'model_13/tf.reshape_5/Reshape_new_shape_0_npu' shape=[3] dtype=int32> adding consumer <nng.Operation 'model_13/tf.reshape_5/Reshape' type=Memcpy>
# <nng.Tensor 'model_13/tf.reshape_5/Reshape' shape=[1, 144, 400] dtype=int8> adding consumer <nng.Operation 'model_13/tf.concat_16/concat1_avgpool' type=AvgPool>
# <nng.Tensor 'model_13/tf.compat.v1.transpose_12/transpose_npu' shape=[1, 144, 10, 10] dtype=int8> adding consumer <nng.Operation 'model_13/tf.reshape_8/Reshape' type=Memcpy>
# <nng.Tensor 'model_13/tf.reshape_8/Reshape_new_shape_0_npu' shape=[3] dtype=int32> adding consumer <nng.Operation 'model_13/tf.reshape_8/Reshape' type=Memcpy>
# <nng.Tensor 'model_13/tf.reshape_8/Reshape' shape=[1, 144, 100] dtype=int8> adding consumer <nng.Operation 'model_13/tf.concat_16/concat2_avgpool' type=AvgPool>
#
# Network summary for yolov8n_full_integer_quant
# Accelerator configuration               Ethos_U55_128
# System configuration                 internal-default
# Memory mode                          internal-default
# Accelerator clock                                 500 MHz
# Design peak SRAM bandwidth                       4.00 GB/s
# Design peak Off-chip Flash bandwidth             0.50 GB/s
#
# Total SRAM used                               2920.31 KiB
# Total Off-chip Flash used                     2154.39 KiB
#
# CPU operators = 4 (1.4%)
# NPU operators = 285 (98.6%)
#
# Average SRAM bandwidth                           2.01 GB/s
# Input   SRAM bandwidth                          54.79 MB/batch
# Weight  SRAM bandwidth                          16.90 MB/batch
# Output  SRAM bandwidth                          30.07 MB/batch
# Total   SRAM bandwidth                         101.82 MB/batch
# Total   SRAM bandwidth            per input    101.82 MB/inference (batch size 1)
#
# Average Off-chip Flash bandwidth                 0.04 GB/s
# Input   Off-chip Flash bandwidth                 0.02 MB/batch
# Weight  Off-chip Flash bandwidth                 2.09 MB/batch
# Output  Off-chip Flash bandwidth                 0.00 MB/batch
# Total   Off-chip Flash bandwidth                 2.13 MB/batch
# Total   Off-chip Flash bandwidth  per input      2.13 MB/inference (batch size 1)
#
# Neural network macs                        1097328800 MACs/batch
# Network Tops/s                                   0.04 Tops/s
#
# NPU cycles                                   23546683 cycles/batch
# SRAM Access cycles                           11008045 cycles/batch
# DRAM Access cycles                                  0 cycles/batch
# On-chip Flash Access cycles                         0 cycles/batch
# Off-chip Flash Access cycles                    20560 cycles/batch
# Total cycles                                 25332272 cycles/batch
#
# Batch Inference time                50.66 ms,   19.74 inferences/s (batch size 1)
